# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Tahmineh Darvishmohammadi**
# Data Analyst

# %% [markdown]
# *I am interested in data science because I want to use it in decision making processes*

# %% [markdown]
# ### My code is supposed to print hello world

# %%
print ("hello world")
# Out:
# hello world

# %% [markdown]
# ***
# - bullet number one
# - bullet number two
#
# | Column | C1 | C2 |
# | --- | --- | --- |
# | R1 | R2 | R3 |
#
# <a href="www.google.com">google</a>
#
# ![328-3280175_transparent-beer-clipart-free-cartoon-beer-transparent-background.png](attachment:328-3280175_transparent-beer-clipart-free-cartoon-beer-transparent-background.png)
